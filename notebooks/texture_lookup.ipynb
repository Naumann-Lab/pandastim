# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import sys
sys.path.append(r'C://Users//Zichen//anaconda3//envs//pandastim//Lib//site-packages//')

import pickle
pickle.HIGHEST_PROTOCOL = 4
import pandas as pd
import numpy as np
from stimuli.textures import TextureBase, CircleRGBTex
#need to grab this from bruker
#from pandastim.utils import dot_generator

# %%
texture = CircleRGBTex(circle_radius = 30)

# %%
texture.view()
